# %%
class Machine:
  def __init__(self, number_of_machine, name_of_path, coordinates, in_progress, on_parking):
    self.number_of_machine = number_of_machine
    self.name_of_path = Path
    self.coordinates = XYZ(0, 0, 0)
    self.in_progress = True
    self.on_parking = False
  def drive(self):
    self.in_progress = True
  def stand(self):
    self.on_parking = True
  def drive(self):
    self.on_parking = False
  def stand(self):
    self.in_progress = False
  def go_to_path(self, Path):
    self.name_of_path = Path

class Drilling_rig(Machine):
  def drill(self):
    pass

class Mapping_paths_machine(Machine):
  def take_cartograms_of_paths(self):
    pass

class Support_inspection_machine(Machine):
  def support_inspection(self):
    pass
  def take_photos_of_support(self):
    pass
  def write_percentage_of_wear(self):
    pass

class Support:
  def __init__(self, number_of_support, percentage_of_wear, arched, trapezoidal):
    self.number_of_support = number_of_support
    self.percentage_of_wear = percentage_of_wear
    self.arched = True or False
    self.trapezoidal = True or False
  def wear(self):
    pass
class Controller:
  def __init__(self, list_of_path_numbers, list_of_machines_numbers):
    self.list_of_path_numbers = []
    self.list_of_machines_numbers = []
  def send_on_path(self):
    pass

class XYZ:
  def __init__(self, x, y, z):
    self.x = x
    self.y = y
    self.z = z
class Tunnel:
  def __init__(self, tunnel_number, coordinates):
    self.tunnel_number = tunnel_number
    self.coordinates = XYZ
  def have_coordinates(self, coordinates):
    return self.coordinates
class Path:
  def __init__(self, path_number):
    self.path_number = path_number
    self.tunnels = []
  def add_tunnel(self, tunnel):
    self.tunnels.append(tunnel)
  def remove_tunnel(self, tunnel):
    self.tunnels.remove(tunnel)
